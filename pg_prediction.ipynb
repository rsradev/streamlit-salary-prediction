# %% [markdown]
# ### LOADING DATA AND CLEANING

# %%
from dataloader import create_cursor
import pandas as pd

# %%
con, cursor = create_cursor()

# %%
cursor.execute("""
            SELECT 
                Country,
                EdLevel,
                YearsCodePro,
                Employment,
                Salary 
            FROM 
               survey
        """)
df = pd.DataFrame(cursor.fetchall(), columns=[
    'Country',
    'EdLevel',
    'YearsCodePro','Employment','Salary'])

# %%
df
# Out:
#                                                  Country  \
# 0                               United States of America
# 1                               United States of America
# 2                               United States of America
# 3                                            Philippines
# 4      United Kingdom of Great Britain and Northern I...
# ...                                                  ...
# 46554                                             Brazil
# 46555                                            Armenia
# 46556                                              India
# 46557                                             France
# 46558                                             Greece
#
#                                                  EdLevel  YearsCodePro  \
# 0           Bachelor’s degree (B.A., B.S., B.Eng., etc.)             9
# 1           Bachelor’s degree (B.A., B.S., B.Eng., etc.)            23
# 2           Bachelor’s degree (B.A., B.S., B.Eng., etc.)             7
# 3           Bachelor’s degree (B.A., B.S., B.Eng., etc.)             4
# 4      Some college/university study without earning ...            21
# ...                                                  ...           ...
# 46554    Master’s degree (M.A., M.S., M.Eng., MBA, etc.)            24
# 46555  Some college/university study without earning ...             2
# 46556       Bachelor’s degree (B.A., B.S., B.Eng., etc.)             2
# 46557    Master’s degree (M.A., M.S., M.Eng., MBA, etc.)             9
# 46558    Master’s degree (M.A., M.S., M.Eng., MBA, etc.)             9
#
#                                               Employment    Salary
# 0                                    Employed, full-time  285000.0
# 1                                    Employed, full-time  250000.0
# 2                                    Employed, full-time  156000.0
# 3      Employed, full-time;Independent contractor, fr...   23456.0
# 4                                    Employed, full-time   96828.0
# ...                                                  ...       ...
# 46554                                Employed, full-time   50719.0
# 46555  Employed, full-time;Independent contractor, fr...   16917.0
# 46556                                Employed, full-time   15752.0
# 46557                                Employed, full-time   64254.0
# 46558                                Employed, full-time   61041.0
#
# [46559 rows x 5 columns]

# %%
df = df[df['Salary'].notnull()]

# %%
df = df.dropna()

# %%
df = df[df['Employment'] == 'Employed, full-time']
df = df.drop('Employment', axis=1)

# %%
def shorten_categories(categories, cutoff):
    cat_map = {}
    for c in range(len(categories)):
        if categories.values[c] >= cutoff:
            cat_map[categories.index[c]] = categories.index[c]
        else:
            cat_map[categories.index[c]] = 'Other'
    return cat_map

# %%
country_map = shorten_categories(df.Country.value_counts(), 400)
df['Country'] = df['Country'].map(country_map)

# %%
df = df[df['Salary'] <= 250_000]
df = df[df['Salary'] >= 10_000]
df = df[df['Salary'] != 'Other']

# %%
def clean_expr(x):
    if x == 'More than 50 years':
        return 50
    elif x == 'Less than 1 year':
        return 0.5
    return float(x)

df['YearsCodePro'] = df['YearsCodePro'].apply(clean_expr)

# %%
def clean_edu(x):
    if 'Bachelor’s degree' in x:
        return "Bachelor's degree"
    elif  'Master’s degree' in x:
        return "Master's degree"
    elif 'Professional degree' in x or 'Other doctoral' in x:
        return 'Post grad'
    return 'Less than a Bachelors'

df['EdLevel'] = df['EdLevel'].apply(clean_edu)

# %% [markdown]
# #### LABELING

# %%
from sklearn.preprocessing import LabelEncoder
le_education = LabelEncoder()
df['EdLevel'] = le_education.fit_transform(df['EdLevel'])
df['EdLevel'].unique()
# Out:
# array([0, 1, 2, 3])

# %%
le_country = LabelEncoder()
df['Country'] = le_country.fit_transform(df['Country'])

# %%
x = df.drop('Salary', axis=1)
y = df['Salary']

# %% [markdown]
# #### MODELS

# %%
from sklearn.linear_model import LinearRegression
linear_reg = LinearRegression()
linear_reg.fit(x, y.values)
# Out:
# LinearRegression()

# %%
y_pred = linear_reg.predict(x)

# %%
y_pred
# Out:
# array([137469.73003383, 107871.81652107, 128285.4796561 , ...,
#         57620.29219559,  59600.35698015,  85692.6510228 ])

# %%
from sklearn.metrics import mean_squared_error, mean_absolute_error
import numpy as np 

error = np.sqrt(mean_squared_error(y, y_pred))

# %%
error
# Out:
# 46626.50300917332

# %%
from sklearn.tree import DecisionTreeRegressor

dec_tree_reg = DecisionTreeRegressor(random_state=0)
dec_tree_reg.fit(x, y.values)
# Out:
# DecisionTreeRegressor(random_state=0)

# %%
y_pred = dec_tree_reg.predict(x)

# %%
error = np.sqrt(mean_squared_error(y, y_pred))

# %%
error
# Out:
# 33308.46543178833

# %%
from sklearn.ensemble import RandomForestRegressor
random_forest_reg = RandomForestRegressor(random_state=0)
random_forest_reg.fit(x, y.values)
# Out:
# RandomForestRegressor(random_state=0)

# %%
y_pred = random_forest_reg.predict(x)

# %%
error = np.sqrt(mean_squared_error(y, y_pred))

# %%
error
# Out:
# 33365.480241250705

# %%
from sklearn.model_selection import GridSearchCV

max_depth = [None, 2,4,6,8,10,12]
parameters = {'max_depth': max_depth}

regressor = DecisionTreeRegressor(random_state=0)
gs = GridSearchCV(regressor, parameters, scoring='neg_mean_squared_error')
gs.fit(x, y.values)
# Out:
# GridSearchCV(estimator=DecisionTreeRegressor(random_state=0),
#              param_grid={'max_depth': [None, 2, 4, 6, 8, 10, 12]},
#              scoring='neg_mean_squared_error')

# %%
regressor = gs.best_estimator_

regressor.fit(x, y.values)
y_pred = regressor.predict(x)
error = np.sqrt(mean_absolute_error(y, y_pred))

# %%
error
# Out:
# 157.9712707381082

# %%
x
# Out:
#        Country  EdLevel  YearsCodePro
# 1           17        0          23.0
# 2           17        0           7.0
# 4           16        1          21.0
# 5           17        1           3.0
# 6           17        0           3.0
# ...        ...      ...           ...
# 46553       11        3           5.0
# 46554        1        2          24.0
# 46556        6        0           2.0
# 46557        4        2           9.0
# 46558       11        2           9.0
#
# [34528 rows x 3 columns]

# %%
x = np.array([['United States of America', "Master's degree", 15]])

# %%
x
# Out:
# array([['United States of America', "Master's degree", '15']],
#       dtype='<U24')

# %%
x[:, 0] = le_country.transform(x[:,0])
x[:, 1] = le_education.transform(x[:,1])
x = x.astype(float)
x
# Out:
# array([[17.,  2., 15.]])

# %%
y_pred = regressor.predict(x)
y_pred
# Out:
# /Users/radi/.pyenv/versions/3.11.2/lib/python3.11/site-packages/sklearn/base.py:493: UserWarning: X does not have valid feature names, but DecisionTreeRegressor was fitted with feature names
#   warnings.warn(
# array([171952.90990991])

# %% [markdown]
# #### STORE MODEL

# %%
import pickle

# %%
data = {
    'model':regressor,
    'le_country': le_country,
    'le_education': le_education
}
with open('./data/steps.pkl', 'wb') as file:
    pickle.dump(data, file)

# %%
with open('./data/steps.pkl', 'rb') as file:
    data = pickle.load(file)

regressor_loades = data['model']
le_country = data['le_country']
le_education = data['le_education']

# %%
y_pred = regressor_loades.predict(x)
y_pred
# Out:
# /Users/radi/.pyenv/versions/3.11.2/lib/python3.11/site-packages/sklearn/base.py:493: UserWarning: X does not have valid feature names, but DecisionTreeRegressor was fitted with feature names
#   warnings.warn(
# array([171952.90990991])
